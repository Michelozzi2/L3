# %%
import numpy as np 
import pandas as pd
import seaborn as sns

# %% [markdown]
# 1.1

# %%
train = pd.read_csv('train.csv',sep=',')
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 1.2

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# 1.3

# %%
train.set_index('PassengerId',inplace=True, drop=True)

# %%
train.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...

# %% [markdown]
# 1.4.1

# %%
column_names = train.columns
print(column_names)
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# 1.4.3

# %%
dtypes = train.dtypes
dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
count = train.count()
count
# Out:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         714
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       204
# Embarked    889
# dtype: int64

# %% [markdown]
# 2.1

# %%
def parse_model_1(train_file):
    train = pd.read_csv(train_file)
    train = train.set_index('PassengerId')
    X = train[['Fare', 'SibSp', 'Parch']]
    y = train['Survived']
    return X, y

X, y = parse_model_1('train.csv')
X.head()
# Out:
#                 Fare  SibSp  Parch
# PassengerId
# 1             7.2500      1      0
# 2            71.2833      1      0
# 3             7.9250      0      0
# 4            53.1000      1      0
# 5             8.0500      0      0

# %% [markdown]
# 2.2.2

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

#2.2.1 on prefere la validation croisée car elle permet de mieux estimer la performance du modèle sur des données non vues et avec un echantillon de petite taille
def compute_score(classifier, X, y):
    scores = cross_val_score(classifier, X, y, cv=5)
    return scores.mean()

classifier = LogisticRegression()
compute_score(classifier, X, y)
# Out:
# 0.6746092524009792

# %% [markdown]
# 3.1.1

# %%
survived = train[train.Survived == 1]
dead = train[train.Survived == 0]
survived
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# ...               ...     ...
# 876                 1       3
# 880                 1       1
# 881                 1       2
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# 3.2.1

# %%
import matplotlib.pyplot as plt

def plot_hist(variable, title):
    plt.hist([dead[variable].dropna(), survived[variable].dropna()], label=['Survived', 'Dead'])
    plt.xlabel(variable)
    plt.ylabel('Number of passengers')
    plt.title(title)
    plt.legend(loc='upper right')
    plt.show()

plot_hist('Pclass','Number of passengers by class')

# %%
#Question 3.2.2 La variable Pclass est importante car elle a un impact sur la survie des passagers

df = pd.read_csv('train.csv')  

survived = df[df['Survived'] == 1]['Pclass'].value_counts()
dead = df[df['Survived'] == 0]['Pclass'].value_counts()
df_new = pd.DataFrame([survived, dead])
df_new.index = ['Survived', 'Dead']
df_new.plot(kind='bar', stacked=True, figsize=(10,5))

plt.show()

# %% [markdown]
# 3.3

# %%
dummies = pd.get_dummies(train['Pclass'], prefix='split_Pclass')
dummies
# Out:
#              split_Pclass_1  split_Pclass_2  split_Pclass_3
# PassengerId
# 1                     False           False            True
# 2                      True           False           False
# 3                     False           False            True
# 4                      True           False           False
# 5                     False           False            True
# ...                     ...             ...             ...
# 887                   False            True           False
# 888                    True           False           False
# 889                   False           False            True
# 890                    True           False           False
# 891                   False           False            True
#
# [891 rows x 3 columns]

# %% [markdown]
# 3.3.1/3.3.2

# %%
def parse_model_2(train_file):
    train = pd.read_csv(train_file)
    train = train.set_index('PassengerId')
    X_2 = train[['SibSp', 'Parch','Fare']].join(dummies)
    y_2 = train['Survived']
    return X_2, y_2

X_2, y_2 = parse_model_2('train.csv')
X_2.head()
# Out:
#              SibSp  Parch     Fare  split_Pclass_1  split_Pclass_2  \
# PassengerId
# 1                1      0   7.2500           False           False
# 2                1      0  71.2833            True           False
# 3                0      0   7.9250           False           False
# 4                1      0  53.1000            True           False
# 5                0      0   8.0500           False           False
#
#              split_Pclass_3
# PassengerId
# 1                      True
# 2                     False
# 3                      True
# 4                     False
# 5                      True

# %% [markdown]
# 3.4.1

# %%
classifier = LogisticRegression(max_iter=1000)
compute_score(classifier, X_2, y_2)
#Question 3.4.2 La performance du modèle est meilleure avec la variable Pclass
# Out:
# 0.6937040989266211

# %% [markdown]
# 3.4.3

# %%
def plot_lr_coefs(X, lr):
    coefs = lr.coef_[0]
    feature_names = X.columns
    plt.bar(feature_names, coefs)
    plt.xlabel('Features')
    plt.ylabel('Coefficient Values')
    plt.title('Logistic Regression Coefficients')
    plt.xticks(rotation=90)
    plt.show()

classifier.fit(X_2, y_2)
plot_lr_coefs(X_2, classifier)

#Question 3.4.4 On constate que les classes 1 et 3 ont un impact plus important que les autres 
#de plus on peut considérer que le poid de fare est négligeable

# %% [markdown]
# 4

# %%
train['Sex'].replace({"female": 0, "male": 1}, inplace=True)
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
# ...                                                        ...  ...   ...
# ...

# %%
sex_dummies = pd.get_dummies(train['Sex'], prefix='split_class')
sex_dummies.columns = ['split_class_female' if '_0' in col else 'split_class_male' for col in sex_dummies.columns]
sex_dummies
# Out:
#              split_class_female  split_class_male
# PassengerId
# 1                         False              True
# 2                          True             False
# 3                          True             False
# 4                          True             False
# 5                         False              True
# ...                         ...               ...
# 887                       False              True
# 888                        True             False
# 889                        True             False
# 890                       False              True
# 891                       False              True
#
# [891 rows x 2 columns]

# %%
average_Age = train['Age'].median()
average_Age
# Out:
# 28.0

# %%
train['Age'].fillna(average_Age, inplace=True)
train.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# 4.1

# %%
def parse_model_3(train_file):
    # Ajouter 'Sex' et 'Age' à la liste des colonnes
    X_3 = train[['Age','SibSp', 'Parch', 'Fare']].join(dummies).join(sex_dummies)
    y_3 = train['Survived']

    return X_3, y_3

X_3, y_3 = parse_model_3('train.csv')
X_3.head()
# Out:
#               Age  SibSp  Parch     Fare  split_Pclass_1  split_Pclass_2  \
# PassengerId
# 1            22.0      1      0   7.2500           False           False
# 2            38.0      1      0  71.2833            True           False
# 3            26.0      0      0   7.9250           False           False
# 4            35.0      1      0  53.1000            True           False
# 5            35.0      0      0   8.0500           False           False
#
#              split_Pclass_3  split_class_female  split_class_male
# PassengerId
# 1                      True               False              True
# 2                     False                True             False
# 3                      True                True             False
# 4                     False                True             False
# 5                      True               False              True

# %%
X_3.isna().sum()
# Out:
# Age                   0
# SibSp                 0
# Parch                 0
# Fare                  0
# split_Pclass_1        0
# split_Pclass_2        0
# split_Pclass_3        0
# split_class_female    0
# split_class_male      0
# dtype: int64

# %% [markdown]
# 4.2.1

# %%
classifier = LogisticRegression(max_iter=1000)
compute_score(classifier, X_3, y_3)
# Out:
# 0.7867553825874083

# %% [markdown]
# 4.2.2

# %% [markdown]
# Question 4.2.3 L'amélioration du modèle semble provenir des variables de type sexe car leurs poids est beaucoup
# plus importants que celui de la variables Age

# %%
classifier.fit(X_3, y_3)
plot_lr_coefs(X_3, classifier)

# %% [markdown]
# 5.1.1

# %%
# 5.2.2 On obtient un score de 0.79 avec la régression logistique et 0.81 avec la forêt aléatoire le modèle de forêt aléatoire est donc meilleur
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_3, y_3)
compute_score(classifier, X_3, y_3)
# Out:
# 0.812623187496077

# %% [markdown]
# 5.2.1

# %%
import pylab as pl

def classifier_importance(X, clf):
    importances = clf.feature_importances_
    indices = np.argsort(importances)[::-1]
    pl.title("Feature importances")
    for tree in clf.estimators_:
        pl.plot(range(X.shape[1]), tree.feature_importances_[indices], "r")
    pl.plot(range(X.shape[1]), importances[indices], "b")
    pl.show()
    for f in range(X.shape[1]):
        print("%d. feature: %s (%f)" % (f+1, X.columns[indices[f]], importances[indices[f]]))

# %% [markdown]
# On remarque que les varia

# %%
# 5.2.2 On constate que les variables les plus importantes sont 'Fare', 'Age' l' age et le tarif du billet sont donc les variables les plus importantes
classifier_importance(X_3, classifier)
# Out:
# 1. feature: Fare (0.275769)
# 2. feature: Age (0.254395)
# 3. feature: split_class_female (0.150247)
# 4. feature: split_class_male (0.140604)
# 5. feature: split_Pclass_3 (0.056548)
# 6. feature: SibSp (0.046197)
# 7. feature: Parch (0.035551)
# 8. feature: split_Pclass_1 (0.024941)
# 9. feature: split_Pclass_2 (0.015746)

# %%
survived = train[train.Survived == 1]
dead = train[train.Survived == 0]
plot_hist('Age', 'Distribution of Age by survival')

# %% [markdown]
# Question 4.3.2 On remarque qu il y a une grande différence entre le nombre de deces ou survivant chez les enfants et les personnes entre 20 et 40 ans,il serait donc interessant de faire une etude des poids de ces 2 variables pour vérifier si elles peuvent influer sur le modele.

# %%
X_3['is_child'] = X_3.Age < 8

# %%
classifier = LogisticRegression(max_iter=1000)
compute_score(classifier, X_3, y_3)
# Out:
# 0.8002134203753689

# %%
classifier.fit(X_3, y_3)
plot_lr_coefs(X_3, classifier)

# %%
classifier = RandomForestClassifier()
classifier.fit(X_3, y_3)
compute_score(classifier, X_3, y_3)

classifier_importance(X_3, classifier)
# Out:
# 1. feature: Fare (0.269081)
# 2. feature: Age (0.242832)
# 3. feature: split_class_female (0.170437)
# 4. feature: split_class_male (0.125623)
# 5. feature: split_Pclass_3 (0.051103)
# 6. feature: SibSp (0.043948)
# 7. feature: Parch (0.033588)
# 8. feature: split_Pclass_1 (0.030764)
# 9. feature: is_child (0.017205)
# 10. feature: split_Pclass_2 (0.015419)

# %% [markdown]
# 5.3.1

# %%
X_3['title'] = train.Name.map(lambda x : x.split(',')[1].split('.')[0])
X_3
# Out:
#               Age  SibSp  Parch     Fare  split_Pclass_1  split_Pclass_2  \
# PassengerId
# 1            22.0      1      0   7.2500           False           False
# 2            38.0      1      0  71.2833            True           False
# 3            26.0      0      0   7.9250           False           False
# 4            35.0      1      0  53.1000            True           False
# 5            35.0      0      0   8.0500           False           False
# ...           ...    ...    ...      ...             ...             ...
# 887          27.0      0      0  13.0000           False            True
# 888          19.0      0      0  30.0000            True           False
# 889          28.0      1      2  23.4500           False           False
# 890          26.0      0      0  30.0000            True           False
# 891          32.0      0      0   7.7500           False           False
#
#              split_Pclass_3  split_class_female  split_class_male  is_child  \
# ...

# %% [markdown]
# 5.3.2

# %%
X_3['cabin'] = train.Cabin.map(lambda x : x[0] if not pd.isnull(x) else -1)
X_3
# Out:
#               Age  SibSp  Parch     Fare  split_Pclass_1  split_Pclass_2  \
# PassengerId
# 1            22.0      1      0   7.2500           False           False
# 2            38.0      1      0  71.2833            True           False
# 3            26.0      0      0   7.9250           False           False
# 4            35.0      1      0  53.1000            True           False
# 5            35.0      0      0   8.0500           False           False
# ...           ...    ...    ...      ...             ...             ...
# 887          27.0      0      0  13.0000           False            True
# 888          19.0      0      0  30.0000            True           False
# 889          28.0      1      2  23.4500           False           False
# 890          26.0      0      0  30.0000            True           False
# 891          32.0      0      0   7.7500           False           False
#
#              split_Pclass_3  split_class_female  split_class_male  is_child  \
# ...

# %%
X_3.head(20)
X_3['cabin'].unique()
# Out:
# array([-1, 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
X_3['title'].unique()
# Out:
# array([' Mr', ' Mrs', ' Miss', ' Master', ' Don', ' Rev', ' Dr', ' Mme',
#        ' Ms', ' Major', ' Lady', ' Sir', ' Mlle', ' Col', ' Capt',
#        ' the Countess', ' Jonkheer'], dtype=object)

# %%
dummies_title = pd.get_dummies(X_3['title'], prefix='split_title')
dummies_title
# Out:
#              split_title_ Capt  split_title_ Col  split_title_ Don  \
# PassengerId
# 1                        False             False             False
# 2                        False             False             False
# 3                        False             False             False
# 4                        False             False             False
# 5                        False             False             False
# ...                        ...               ...               ...
# 887                      False             False             False
# 888                      False             False             False
# 889                      False             False             False
# 890                      False             False             False
# 891                      False             False             False
#
#              split_title_ Dr  split_title_ Jonkheer  split_title_ Lady  \
# PassengerId
# ...

# %%
dummies_cabin = pd.get_dummies(X_3['cabin'], prefix='split_cabin')
dummies_cabin
# Out:
#              split_cabin_-1  split_cabin_A  split_cabin_B  split_cabin_C  \
# PassengerId
# 1                      True          False          False          False
# 2                     False          False          False           True
# 3                      True          False          False          False
# 4                     False          False          False           True
# 5                      True          False          False          False
# ...                     ...            ...            ...            ...
# 887                    True          False          False          False
# 888                   False          False           True          False
# 889                    True          False          False          False
# 890                   False          False          False           True
# 891                    True          False          False          False
#
#              split_cabin_D  split_cabin_E  split_cabin_F  split_cabin_G  \
# ...

# %% [markdown]
# 5.3.3

# %%
def parse_model_5(train_file):
    X_3 = train[['Age','SibSp', 'Parch', 'Fare']].join(dummies).join(sex_dummies).join(dummies_cabin).join(dummies_title)
    y_3 = train['Survived']

    return X_3, y_3

X_3, y_3 = parse_model_5('train.csv')
X_3.head()
# Out:
#               Age  SibSp  Parch     Fare  split_Pclass_1  split_Pclass_2  \
# PassengerId
# 1            22.0      1      0   7.2500           False           False
# 2            38.0      1      0  71.2833            True           False
# 3            26.0      0      0   7.9250           False           False
# 4            35.0      1      0  53.1000            True           False
# 5            35.0      0      0   8.0500           False           False
#
#              split_Pclass_3  split_class_female  split_class_male  \
# PassengerId
# 1                      True               False              True
# 2                     False                True             False
# 3                      True                True             False
# 4                     False                True             False
# 5                      True               False              True
#
#              split_cabin_-1  ...  split_title_ Master  split_title_ Miss  \
# ...

# %%
column_names = X_3.columns
print(column_names)
# Out:
# Index(['Age', 'SibSp', 'Parch', 'Fare', 'split_Pclass_1', 'split_Pclass_2',
#        'split_Pclass_3', 'split_class_female', 'split_class_male',
#        'split_cabin_-1', 'split_cabin_A', 'split_cabin_B', 'split_cabin_C',
#        'split_cabin_D', 'split_cabin_E', 'split_cabin_F', 'split_cabin_G',
#        'split_cabin_T', 'split_title_ Capt', 'split_title_ Col',
#        'split_title_ Don', 'split_title_ Dr', 'split_title_ Jonkheer',
#        'split_title_ Lady', 'split_title_ Major', 'split_title_ Master',
#        'split_title_ Miss', 'split_title_ Mlle', 'split_title_ Mme',
#        'split_title_ Mr', 'split_title_ Mrs', 'split_title_ Ms',
#        'split_title_ Rev', 'split_title_ Sir', 'split_title_ the Countess'],
#       dtype='object')

# %% [markdown]
# 5.3.4

# %%
# 5.3.5 On constate que le score de la régression logistique est de 0.82 et celui de la forêt aléatoire est de 0.81 le modèle de 
# régression logistique est donc meilleur lorsqu'on ajoute des variables comme'title' et 'cabin'
classifier = LogisticRegression(max_iter=1000)
compute_score(classifier, X_3, y_3)
# Out:
# 0.8237900947837549
